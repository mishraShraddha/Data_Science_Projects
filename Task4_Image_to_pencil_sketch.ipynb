# %% [markdown]
# <a href="https://colab.research.google.com/github/mishraShraddha/LGMVIP-Data-science/blob/main/Task4_Image_to_pencil_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Name**: **Shraddha** **Mishra**<br>
# **Task** **4**: **Image** **to** **pencil** **sketch** **with** **python**<br>
# **Data** **Science** **Intern** **at** **Let**'s **Grow** **More**

# %%
import cv2

# %% [markdown]
# **Loading** **Original** **Image**

# %%
from google.colab.patches import cv2_imshow
image = cv2.imread("Stark.jpg")
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x692 at 0x7F909C795250>
# -1

# %% [markdown]
# **Coverting** **Original** **Image** **to** **Gray** **Scale** **Image**

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1024x692 at 0x7F909BF3A090>
# -1

# %% [markdown]
# **Inverting** **the** **image**

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=L size=1024x692 at 0x7F909C7A5B90>
# -1

# %% [markdown]
# **Blur** **The** **Image**

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %% [markdown]
# **Invert** **the** **blur** **image**

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=1024x692 at 0x7F909C7AED10>
# -1

# %% [markdown]
# **Original** **and** **pencil** **sketch** **image**

# %%
cv2_imshow(image)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=1024x692 at 0x7F909BF31610>
# <PIL.Image.Image image mode=L size=1024x692 at 0x7F909BF31BD0>
# -1
